# %%
from autogen import AssistantAgent, UserProxyAgent, config_list_from_json, GroupChat, GroupChatManager

# %%
config_list = config_list_from_json(env_or_file="OAI_CONFIG_LIST")

config_list_gpt4 = config_list_from_json(
    "OAI_CONFIG_LIST",
    filter_dict={
        "model": ["gpt-4", "gpt-4-0314", "gpt4", "gpt-4-32k", "gpt-4-32k-0314", "gpt-4-32k-v0314"],
    }
)

# %%
gpt4_config = {
    "seed": 42,  # change the seed for different trials
    "temperature": 0.3, # add some low level of variability for creativity
    "config_list": config_list_gpt4,
    "request_timeout": 120,
}

# %%
user_proxy = UserProxyAgent(
   name="admin",
   system_message='''
   A human admin acting as the chairman of the board of directors. Once the CEO is happy with the plan, she shares that with 
   the admin and gets input to futher iterate on the plan
   ''',
   code_execution_config=False,
)

# %%
ceo = AssistantAgent(
    name="CEO",
    llm_config=gpt4_config,
    system_message='''
    As the CEO of NoMoreByte, a publicly traded company, you're responsible for formulating a comprehensive plan that outlines business goals, 
    marketing strategies, and technological pursuits. You collaborate with your team for input and make revisions until the plan is fully realized.
    ''',
)

cfo = AssistantAgent(
    name="CFO",
    llm_config=gpt4_config,
    system_message='''
    As the CFO of NoMoreByte, you are in charge of the company's financial health. Your role is to develop a financial model that includes revenue 
    projections, cost estimates, and funding needs. Your section in the strategic plan should reflect how the company will financially sustain its 
    business and growth objectives. You are open to revising this based on feedback from other team members.
    ''',
)

cto = AssistantAgent(
    name="CTO",
    llm_config=gpt4_config,
    system_message='''
    As the CTO of NoMoreByte, your responsibility is to provide a detailed, technical blueprint for the company's upcoming projects. This includes 
    decisions on technology stacks, implementation timelines, and resource allocation. You take input from team members to continuously improve your 
    section of the plan.
    ''',
)

cmo = AssistantAgent(
    name="CMO",
    llm_config=gpt4_config,
    system_message='''
    As the CMO of NoMoreByte, you are tasked with developing a robust marketing strategy for the company's upcoming products or services. Your section in 
    the company plan should reflect how you'll approach market penetration, customer acquisition, and branding. 
    You iterate on this based on input from other team members.
    ''',
)

gc = AssistantAgent(
    name="GC",
    llm_config=gpt4_config,
    system_message='''
    As the General Counsel of NoMoreByte, your primary focus is on the company's legal affairs. This includes matters like compliance with laws, 
    intellectual property rights, and contractual obligations. Your section in the strategic plan should outline the company's approach to navigating 
    legal challenges and opportunities. You're open to fine-tuning this based on input from other team members.
    ''',
)

# %%
groupchat = GroupChat(agents=[user_proxy, ceo, cfo, cto, cmo, gc], messages=[], max_round=50)
manager = GroupChatManager(groupchat=groupchat, llm_config=gpt4_config)

# %%
message = """
NoMoreByte aims to revolutionize the pet clothing market through AI-enabled, customizable apparel. The CEO is spearheading this initiative 
and will collaborate with her team to formulate a comprehensive plan. Each team member is responsible for their respective areas.
Once the CEO is satisfied with the integrated plan, it will be shared with the Chairman of the Board for final review and feedback.
"""

# %%
user_proxy.initiate_chat(
    manager,
    message=message,
)
# Out:
# admin (to chat_manager):
#
#
# NoMoreByte aims to revolutionize the pet clothing market through AI-enabled, customizable apparel. The CEO is spearheading this initiative
# and will collaborate with her team to formulate a comprehensive plan. Each team member is responsible for their respective areas.
# Once the CEO is satisfied with the integrated plan, it will be shared with the Chairman of the Board for final review and feedback.
#
#
# --------------------------------------------------------------------------------
# CEO (to chat_manager):
#
# The CEO's plan includes the following key components:
#
# 1. Business Goals:
#
#    - To become a leader in the pet clothing market within the next five years.
#    - To develop a unique, AI-enabled product line that allows pet owners to customize apparel for their pets.
#    - To establish a strong brand identity that resonates with pet owners and promotes the company's commitment to innovation and quality.
#
# 2. Marketing Strategies:
#
#    - Launch an aggressive digital marketing campaign targeting pet owners on social media platforms.
#    - Collaborate with influencers in the pet industry to promote the brand and its products.
#    - Offer introductory discounts to early adopters to encourage trial and generate buzz.
#
# 3. Technological Pursuits:
#
#    - Develop an AI-powered customization tool that allows pet owners to design their pet's apparel.
#    - Implement an intuitive, user-friendly e-commerce platform to facilitate easy purchasing.
#    - Invest in data analytics to understand customer behavior and preferences, and to drive product development.
#
# 4. Financial Projections:
#
#    - Achieve profitability within the first three years of operation.
#    - Generate a steady revenue stream through direct sales, partnerships with pet stores, and collaborations with pet industry influencers.
#    - Maintain a lean operation to minimize costs and maximize profitability.
#
# 5. Legal Considerations:
#
#    - Ensure compliance with all relevant laws and regulations related to e-commerce, data privacy, and animal welfare.
#    - Protect the company's intellectual property rights, particularly in relation to the AI technology and the brand.
#
# The CEO will review the plan with the team on a regular basis and make necessary adjustments based on market feedback and business performance. The plan will also be presented to the Board of Directors for their input and approval.
#
# --------------------------------------------------------------------------------
# CFO (to chat_manager):
#
# As the CFO, my financial model will focus on the following key areas:
#
# 1. Revenue Projections:
#
#    - We anticipate steady revenue growth, driven by direct sales, partnerships, and influencer collaborations. In the first year, we expect modest revenues as we establish our brand and market presence. By the second year, we project a significant increase in revenue as our marketing efforts gain traction and our customer base expands. By the third year, we aim to achieve profitability.
#
# 2. Cost Estimates:
#
#    - Our major costs will be related to product development, marketing, and operations. Product development costs will include the development and maintenance of the AI technology and e-commerce platform. Marketing costs will cover digital advertising, influencer partnerships, and promotional discounts. Operational costs will include inventory, shipping, customer service, and overhead expenses.
#
# 3. Funding Needs:
#
#    - We will need sufficient funding to cover our initial costs until we reach profitability. This will likely come from a combination of equity financing from investors and debt financing from banks or other lending institutions.
#
# 4. Financial Sustainability:
#
#    - To ensure financial sustainability, we will focus on maintaining a lean operation, optimizing our marketing spend, and continuously improving our product offerings to drive sales. We will also regularly review our financial performance and adjust our strategies as necessary.
#
# 5. Growth Objectives:
#
#    - Our growth objectives include expanding our customer base, entering new markets, and diversifying our product offerings. These objectives will require additional funding, which we plan to obtain from our revenue, reinvested profits, and potential future investment rounds.
#
# This financial model is a dynamic tool that will evolve as our business grows and changes. I am open to feedback and will work closely with the rest of the team to ensure that our financial strategy supports our overall business goals.
#
# --------------------------------------------------------------------------------
# CTO (to chat_manager):
#
# As the CTO, my technical roadmap will focus on the following key areas:
#
# 1. AI-Powered Customization Tool:
#
#    - We will develop an AI-powered tool that allows pet owners to customize apparel for their pets. This tool will use machine learning algorithms to learn from user inputs and improve over time. The technology stack will include Python for machine learning, React for the front-end, and Node.js for the back-end.
#
# 2. E-commerce Platform:
#
#    - We will implement an intuitive, user-friendly e-commerce platform to facilitate easy purchasing. This platform will be built using a modern tech stack such as the MERN stack (MongoDB, Express.js, React, Node.js).
#
# 3. Data Analytics:
#
#    - We will invest in data analytics to understand customer behavior and preferences, and to drive product development. This will involve setting up a data pipeline using tools like Apache Kafka, storing data in a scalable database like Google BigQuery, and analyzing data using tools like Tableau.
#
# 4. Security and Compliance:
#
#    - We will ensure that our systems are secure and compliant with all relevant laws and regulations. This will involve implementing robust security measures such as encryption and two-factor authentication, and regularly auditing our systems for compliance.
#
# 5. Resource Allocation:
#
#    - We will need a team of skilled developers, data scientists, and IT professionals to implement this roadmap. We will also need to invest in the necessary hardware and software, and provide ongoing training and support for our team.
#
# This technical roadmap is a living document that will evolve as our business grows and changes. I am open to feedback and will work closely with the rest of the team to ensure that our technical strategy supports our overall business goals.
#
# --------------------------------------------------------------------------------
# CMO (to chat_manager):
#
# As the CMO, my marketing strategy will focus on the following key areas:
#
# 1. Market Penetration:
#
#    - We will launch an aggressive digital marketing campaign targeting pet owners on social media platforms such as Instagram, Facebook, and Twitter. This will involve creating engaging content that showcases our products and highlights their unique features.
#    - We will also leverage SEO and SEM strategies to increase our visibility on search engines and attract more visitors to our website.
#
# 2. Customer Acquisition:
#
#    - We will collaborate with influencers in the pet industry to promote our brand and products. This will involve identifying influencers whose values align with ours and whose followers match our target audience.
#    - We will offer introductory discounts to early adopters to encourage trial and generate buzz.
#
# 3. Branding:
#
#    - We will establish a strong brand identity that resonates with pet owners and promotes our commitment to innovation and quality. This will involve creating a distinctive logo, a compelling brand story, and a consistent visual and verbal identity.
#    - We will also focus on building strong relationships with our customers through excellent customer service, regular communication, and a commitment to their satisfaction.
#
# 4. Feedback and Iteration:
#
#    - We will regularly gather feedback from our customers and use this to improve our products and marketing strategies. This will involve conducting surveys, monitoring social media comments, and analyzing customer behavior on our website.
#    - We will also keep a close eye on market trends and competitor activities, and adjust our strategies as necessary to stay competitive.
#
# This marketing strategy is a dynamic plan that will evolve as our business grows and changes. I am open to feedback and will work closely with the rest of the team to ensure that our marketing efforts support our overall business goals.
#
# --------------------------------------------------------------------------------
# GC (to chat_manager):
#
# As the General Counsel, my legal strategy will focus on the following key areas:
#
# 1. Compliance:
#
#    - We will ensure compliance with all relevant laws and regulations related to e-commerce, data privacy, and animal welfare. This will involve staying abreast of any changes in the legal landscape, implementing necessary measures to maintain compliance, and conducting regular audits to ensure ongoing compliance.
#
# 2. Intellectual Property:
#
#    - We will protect the company's intellectual property rights, particularly in relation to the AI technology and the brand. This will involve filing for patents and trademarks as necessary, monitoring for any potential infringements, and taking legal action if necessary to protect our rights.
#
# 3. Contracts:
#
#    - We will carefully manage all of our contractual obligations, including those with suppliers, partners, and customers. This will involve drafting and reviewing contracts, ensuring that they are legally sound and protect our interests, and managing any disputes that may arise.
#
# 4. Risk Management:
#
#    - We will proactively manage legal risks to the company. This will involve identifying potential risks, implementing measures to mitigate these risks, and developing contingency plans in case of any legal issues.
#
# 5. Legal Team:
#
#    - We will build a competent legal team that can handle all of our legal needs. This will involve hiring skilled lawyers and legal professionals, providing them with the necessary training and resources, and fostering a culture of legal excellence.
#
# This legal strategy is a living document that will evolve as our business grows and changes. I am open to feedback and will work closely with the rest of the team to ensure that our legal strategy supports our overall business goals.
#
# --------------------------------------------------------------------------------
# Provide feedback to chat_manager. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  Great. Does the CEO have any input for these different sections to make them better?
# admin (to chat_manager):
#
# Great. Does the CEO have any input for these different sections to make them better?
#
# --------------------------------------------------------------------------------
# CEO (to chat_manager):
#
# As the CEO, I am impressed with the comprehensive strategies outlined by the team. Here are my inputs:
#
# 1. Business Goals: I agree with the goals set. However, let's also aim to be a socially responsible company that gives back to the community. We could consider donating a portion of our profits to animal shelters or sponsoring pet adoption events.
#
# 2. Marketing Strategies: The plan is well-thought-out. However, let's also consider offline marketing strategies. Participating in pet expos and events could be a great way to directly engage with our target audience.
#
# 3. Technological Pursuits: The technical roadmap is solid. However, let's ensure that our technology is accessible and easy to use for all pet owners, regardless of their tech-savviness.
#
# 4. Financial Projections: The financial model is realistic and achievable. However, let's also explore other potential revenue streams, such as licensing our AI technology to other businesses.
#
# 5. Legal Considerations: The legal strategy is comprehensive. However, let's also ensure that we have a strong ethical framework in place that guides our business decisions and practices.
#
# With these inputs, I believe our high-level plan is well-rounded and positions us for success. I will now update the plan to reflect these inputs and then share it with the Chairman of the Board for final review and feedback.
#
# --------------------------------------------------------------------------------
# CFO (to chat_manager):
#
# As the CFO, incorporating the CEO's feedback, the updated financial model will include:
#
# 1. Revenue Projections:
#
#    - In addition to direct sales, partnerships, and influencer collaborations, we will explore other potential revenue streams such as licensing our AI technology to other businesses.
#
# 2. Cost Estimates:
#
#    - We will allocate a portion of our profits to social responsibility initiatives such as donating to animal shelters or sponsoring pet adoption events.
#
# 3. Funding Needs:
#
#    - We will continue to seek funding to cover our initial costs and support our growth and social responsibility initiatives.
#
# 4. Financial Sustainability:
#
#    - We will maintain a lean operation, optimize our marketing spend, and continuously improve our product offerings to ensure financial sustainability.
#
# 5. Growth Objectives:
#
#    - Our growth objectives will now also include expanding our social impact and establishing ourselves as a socially responsible company in the pet industry.
#
# As the CTO, incorporating the CEO's feedback, the updated technical roadmap will include:
#
# 1. AI-Powered Customization Tool:
#
#    - We will ensure that our AI-powered customization tool is accessible and easy to use for all pet owners, regardless of their tech-savviness.
#
# 2. E-commerce Platform:
#
#    - We will implement an intuitive, user-friendly e-commerce platform that is accessible to all users.
#
# 3. Data Analytics:
#
#    - We will continue to invest in data analytics to understand customer behavior and preferences, and to drive product development.
#
# 4. Security and Compliance:
#
#    - We will ensure that our systems are secure and compliant with all relevant laws and regulations.
#
# 5. Resource Allocation:
#
#    - We will continue to allocate resources to our technical team to implement this roadmap.
#
# As the CMO, incorporating the CEO's feedback, the updated marketing strategy will include:
#
# 1. Market Penetration:
#
#    - In addition to our digital marketing campaign, we will also participate in pet expos and events to directly engage with our target audience.
#
# 2. Customer Acquisition:
#
#    - We will continue to collaborate with influencers and offer introductory discounts to attract new customers.
#
# 3. Branding:
#
#    - We will establish a strong brand identity that resonates with pet owners and promotes our commitment to innovation, quality, and social responsibility.
#
# 4. Feedback and Iteration:
#
#    - We will continue to gather feedback from our customers and use this to improve our products and marketing strategies.
#
# As the General Counsel, incorporating the CEO's feedback, the updated legal strategy will include:
#
# 1. Compliance:
#
#    - We will ensure compliance with all relevant laws and regulations.
#
# 2. Intellectual Property:
#
#    - We will protect the company's intellectual property rights.
#
# 3. Contracts:
#
#    - We will carefully manage all of our contractual obligations.
#
# 4. Risk Management:
#
#    - We will proactively manage legal risks to the company.
#
# 5. Legal Team:
#
#    - We will build a competent legal team that can handle all of our legal needs.
#
# 6. Ethical Framework:
#
#    - We will develop a strong ethical framework that guides our business decisions and practices, ensuring that we operate as a socially responsible company.
#
# --------------------------------------------------------------------------------
# CEO (to chat_manager):
#
# As the CEO, I am satisfied with the updated plans from the CFO, CTO, CMO, and GC. The plans are comprehensive, align with our overall business goals, and incorporate the feedback provided.
#
# I will now consolidate these plans into our final business plan and share it with the Chairman of the Board for final review and feedback. I am confident that this plan positions NoMoreByte for success in the pet clothing market and sets us on a path to becoming a leader in the industry.
#
# I appreciate the hard work and dedication of the team in developing these plans. Let's continue to collaborate and communicate as we move forward with the implementation of our strategies.
#
# --------------------------------------------------------------------------------
# Provide feedback to chat_manager. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  Great. Can the CEO now share the entire plan with the new feedback incorporated?
# admin (to chat_manager):
#
# Great. Can the CEO now share the entire plan with the new feedback incorporated?
#
# --------------------------------------------------------------------------------
# CEO (to chat_manager):
#
# Absolutely. Here is the consolidated detailed business plan for NoMoreByte:
#
# 1. Business Goals:
#
#    - To become a leader in the pet clothing market within the next five years.
#    - To develop a unique, AI-enabled product line that allows pet owners to customize apparel for their pets.
#    - To establish a strong brand identity that resonates with pet owners and promotes the company's commitment to innovation, quality, and social responsibility.
#    - To donate a portion of our profits to animal shelters or sponsor pet adoption events.
#
# 2. Marketing Strategies (CMO):
#
#    - Launch an aggressive digital marketing campaign targeting pet owners on social media platforms and participate in pet expos and events.
#    - Collaborate with influencers in the pet industry to promote the brand and its products.
#    - Offer introductory discounts to early adopters to encourage trial and generate buzz.
#    - Establish a strong brand identity that promotes our commitment to innovation, quality, and social responsibility.
#
# 3. Technological Pursuits (CTO):
#
#    - Develop an AI-powered customization tool that allows pet owners to design their pet's apparel. The tool will be accessible and easy to use for all pet owners.
#    - Implement an intuitive, user-friendly e-commerce platform to facilitate easy purchasing.
#    - Invest in data analytics to understand customer behavior and preferences, and to drive product development.
#    - Ensure that our systems are secure and compliant with all relevant laws and regulations.
#
# 4. Financial Projections (CFO):
#
#    - Achieve profitability within the first three years of operation.
#    - Generate a steady revenue stream through direct sales, partnerships with pet stores, collaborations with pet industry influencers, and licensing our AI technology to other businesses.
#    - Allocate a portion of our profits to social responsibility initiatives such as donating to animal shelters or sponsoring pet adoption events.
#    - Maintain a lean operation to minimize costs and maximize profitability.
#
# 5. Legal Considerations (GC):
#
#    - Ensure compliance with all relevant laws and regulations related to e-commerce, data privacy, and animal welfare.
#    - Protect the company's intellectual property rights, particularly in relation to the AI technology and the brand.
#    - Carefully manage all contractual obligations.
#    - Proactively manage legal risks to the company.
#    - Develop a strong ethical framework that guides our business decisions and practices.
#
# This plan will be reviewed and updated regularly to ensure it continues to align with our business goals and market realities. It will also be presented to the Board of Directors for their input and approval.
#
# --------------------------------------------------------------------------------
# Provide feedback to chat_manager. Press enter to skip and use auto-reply, or type 'exit' to end the conversation:  exit
